# %%
import sklearn
print("✅ scikit-learn is installed. Version:", sklearn.__version__)
# Out:
# ✅ scikit-learn is installed. Version: 1.6.1

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import sklearn
print("✅ scikit-learn is installed. Version:", sklearn.__version__)
# Out:
# ✅ scikit-learn is installed. Version: 1.6.1

# %%
from sklearn.linear_model import LinearRegression

# Train the AI Model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict on Test Data
y_pred = model.predict(X_test)

print("✅ AI Model trained successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 # Train the AI Model
#       4 model = LinearRegression()
# ----> 5 model.fit(X_train, y_train)
#       7 # Predict on Test Data
#       8 y_pred = model.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
import pandas as pd
import numpy as np
import talib

# Load BTC price data
df = pd.read_csv("btc_usdt_data.csv")  

# 📈 Moving Averages
df["SMA_20"] = talib.SMA(df["close"], timeperiod=20)  # 20-day simple moving average
df["EMA_20"] = talib.EMA(df["close"], timeperiod=20)  # 20-day exponential moving average

# 📊 RSI (Momentum Indicator)
df["RSI_14"] = talib.RSI(df["close"], timeperiod=14)  

# 🔄 MACD (Trend Reversal Indicator)
df["MACD"], df["MACD_signal"], df["MACD_hist"] = talib.MACD(df["close"], fastperiod=12, slowperiod=26, signalperiod=9)

# 🎯 Bollinger Bands (Volatility Indicator)
df["Upper_Band"], df["Middle_Band"], df["Lower_Band"] = talib.BBANDS(df["close"], timeperiod=20, nbdevup=2, nbdevdn=2)

# 🔥 Stochastic Oscillator (Helps detect overbought/oversold conditions)
df["Stoch_K"], df["Stoch_D"] = talib.STOCH(df["high"], df["low"], df["close"], fastk_period=14, slowk_period=3, slowd_period=3)

# 🌎 Sentiment Scores (Twitter, Google Trends, News)
df["Twitter_Sentiment"] = twitter_sentiment
df["Google_Trends"] = google_trends_score
df["News_Sentiment"] = news_sentiment

# Drop NaN values (some indicators take time to calculate)
df.dropna(inplace=True)

print("✅ Advanced AI Training Data Ready!")
df.tail()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import talib
#       5 # Load BTC price data
# ----> 6 df = pd.read_csv("btc_usdt_data.csv")
#       8 # 📈 Moving Averages
#       9 df["SMA_20"] = talib.SMA(df["close"], timeperiod=20)  # 20-day simple moving average
#
# ...

# %%
import pandas as pd
import talib

# Load BTC price data
df = pd.read_csv("btc_usdt_data.csv")  

# Test if the data loads correctly
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 import talib
#       4 # Load BTC price data
# ----> 5 df = pd.read_csv("btc_usdt_data.csv")
#       7 # Test if the data loads correctly
#       8 print(df.head())
#
# ...

# %%
import pandas as pd
import ccxt

# Initialize Kraken Exchange API
kraken = ccxt.kraken()

# Fetch BTC/USDT historical market data
bars = kraken.fetch_ohlcv("BTC/USDT", timeframe="1h", limit=500)

# Convert to DataFrame
df = pd.DataFrame(bars, columns=["timestamp", "open", "high", "low", "close", "volume"])

# Convert timestamp to readable date
df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms")

# Save to CSV
df.to_csv("btc_usdt_data.csv", index=False)

print("✅ Market data saved as btc_usdt_data.csv!")
# Out:
# ✅ Market data saved as btc_usdt_data.csv!

# %%
import pandas as pd
import talib

# Load BTC price data
df = pd.read_csv("btc_usdt_data.csv")  

# Test if the data loads correctly
print(df.head())
# Out:
#              timestamp     open     high      low    close    volume
# 0  2025-02-16 16:00:00  96975.1  97094.7  96943.9  97043.0  0.930177
# 1  2025-02-16 17:00:00  97042.9  97153.4  97000.0  97000.0  1.295601
# 2  2025-02-16 18:00:00  97000.1  97000.1  96749.1  96899.5  0.984541
# 3  2025-02-16 19:00:00  96864.2  97100.4  96766.3  97050.9  1.577790
# 4  2025-02-16 20:00:00  97050.2  97165.0  96903.1  96911.5  0.327872

# %%
import time
import ccxt

# Initialize Kraken Exchange API
kraken = ccxt.kraken()

def get_live_price():
    """Fetches live BTC/USDT price from Kraken."""
    ticker = kraken.fetch_ticker("BTC/USDT")
    return ticker["last"]  # Last traded price

# Live Price Tracking
while True:
    btc_price = get_live_price()
    print(f"📊 Live BTC Price: ${btc_price:.2f}")
    time.sleep(10)  # Check price every 10 seconds
# Out:
# 📊 Live BTC Price: $84841.10
# 📊 Live BTC Price: $84841.10
# 📊 Live BTC Price: $84841.10
# 📊 Live BTC Price: $84841.10
# 📊 Live BTC Price: $84841.10
# 📊 Live BTC Price: $84841.10
# 📊 Live BTC Price: $84841.10
# 📊 Live BTC Price: $84841.10
# 📊 Live BTC Price: $84817.70
# 📊 Live BTC Price: $84817.70
# 📊 Live BTC Price: $84817.70
# 📊 Live BTC Price: $84817.70
# 📊 Live BTC Price: $84817.70
# 📊 Live BTC Price: $84817.70
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84804.40
# 📊 Live BTC Price: $84806.90
# 📊 Live BTC Price: $84806.90
# 📊 Live BTC Price: $84806.90
# 📊 Live BTC Price: $84806.90
# 📊 Live BTC Price: $84806.90
# 📊 Live BTC Price: $84806.90
# ...

# %%
import requests

# 🔑 Replace with your Telegram Bot Token and Chat ID
TELEGRAM_BOT_TOKEN = "7435926260:AAH-oLyu1KjdmIcFP7QOPetu-bEobWuM32M"
TELEGRAM_CHAT_ID = "1756558101"

def send_telegram_notification(message):
    """Sends a message to your Telegram chat."""
    url = f"https://api.telegram.org/bot{TELEGRAM_BOT_TOKEN}/sendMessage"
    payload = {"chat_id": TELEGRAM_CHAT_ID, "text": message}
    requests.post(url, data=payload)
    print("💬 Telegram Alert Sent!")

# Test Telegram Alert
send_telegram_notification("🚀 BTC just hit $50K! Buy Now!")

# %%
https://api.telegram.org/7435926260:AAH-oLyu1KjdmIcFP7QOPetu-bEobWuM32M/sendMessage?chat_id=1756558101&text=Hello! This is a test.

# %%
import requests

# 🔑 Replace with your actual bot token & chat ID
TELEGRAM_BOT_TOKEN = "7435926260:AAH-oLyu1KjdmIcFP7QOPetu-bEobWuM32M"
TELEGRAM_CHAT_ID = "1756558101"

def send_telegram_notification(message):
    """Sends an alert to a Telegram chat."""
    url = f"https://api.telegram.org/bot{7435926260:AAH-oLyu1KjdmIcFP7QOPetu-bEobWuM32M}/sendMessage"
    payload = {"chat_id": 1756558101, "text": message}
    
    response = requests.post(url, data=payload)

    if response.status_code == 200:
        print("✅ Telegram Alert Sent!")
    else:
        print(f"❌ Telegram Error: {response.json()}")

# Test Telegram Alert
send_telegram_notification("🚀 BTC is pumping! Time to trade!")

# %%
import time

while True:
    btc_price = get_live_price()
    print(f"📊 Live BTC Price: ${btc_price:.2f}")

    if btc_price > 50000:
        send_telegram_notification(f"🚀 BTC just broke $50K! Buy Now!")
    
    elif btc_price < 30000:
        send_telegram_notification(f"📉 BTC dropped below $30K! Watch out!")

    time.sleep(60)  # Check price every minute

# %%
import requests

# 🔑 Replace with your actual bot token & chat ID
TELEGRAM_BOT_TOKEN = "7435926260:AAH-oLyu1KjdmIcFP7QOPetu-bEobWuM32M"
TELEGRAM_CHAT_ID = "1756558101"

def send_telegram_notification(message):
    """Sends an alert to a Telegram chat."""
    url = f"https://api.telegram.org/bot{TELEGRAM_BOT_TOKEN}/sendMessage"
    payload = {"chat_id": TELEGRAM_CHAT_ID, "text": message}
    
    response = requests.post(url, data=payload)

    if response.status_code == 200:
        print("✅ Telegram Alert Sent!")
    else:
        print(f"❌ Telegram Error: {response.json()}")  # Print the error message

# Test Telegram Alert
send_telegram_notification("🚀 BTC is pumping! Time to trade!")
